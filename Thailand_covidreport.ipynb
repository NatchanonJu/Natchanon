# %%
import pandas as pd

# %%
TLCP = pd.read_json('timeline-cases-by-provinces.json')
R12P = pd.read_json('round-1to2-by-provinces.json')

# %%
R12P_NEW = R12P[R12P['province'] == "กรุงเทพมหานคร"]
TLCP_NEW = TLCP[TLCP['province']=="กรุงเทพมหานคร"]
BKK_CASE = R12P_NEW.append(TLCP_NEW) #Bangkok daily case dataframe
Provinces_CASE = R12P.append(TLCP) #Provinces daily case dataframe

# %%
Provinces_CASE_2021 = Provinces_CASE[Provinces_CASE['txn_date']>'2021-01-01']
BKK_CASE_2021 = BKK_CASE[BKK_CASE['txn_date']>'2021-01-01']
Provinces_CASE_2021_pivoted = Provinces_CASE_2021.pivot(index='txn_date', columns='province', values='new_case')

# %%
Thailand_CASE_2021 = Provinces_CASE_2021.groupby(['txn_date']).sum() # grouping by date in order to produce Thailand case

# %%
Provinces_CASE_2021_pivoted.plot(figsize=(13,8), legend=None)
# Out:
# <AxesSubplot:xlabel='txn_date'>

# %%
Thailand_CASE_2021.plot(y='new_case',figsize=(13,9)) #Thailand daily graph
# Out:
# <AxesSubplot:xlabel='txn_date'>

# %%
BKK_CASE_2021.plot(x='txn_date', y='new_case',figsize=(13,8))
# Out:
# <AxesSubplot:xlabel='txn_date'>
